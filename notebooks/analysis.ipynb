# %% [markdown]
# # First Part

# %% [markdown]
# This first part was how I (Bello) filtered the data and the years I maintained. I left it in so we can see what was removed and whats left.
#
# To be removed later

# %%
import pandas as pd

# %%
data = pd.read_parquet("../data/raw/property-tax-report.parquet")

# %%
data.head()
# Out:
#            pid legal_type         folio land_coordinate zoning_district  \
# 0  024-179-370     STRATA  601109050098        60110905            RM-6
# 1  003-898-121     STRATA  616117750040        61611775           RM-5A
# 2  017-341-248     STRATA  600110060012        60011006            RM-6
# 3  006-473-601     STRATA  616118980040        61611898           RM-5A
# 4  007-742-452     STRATA  611108050023        61110805           RM-5B
#
#   zoning_classification lot     plan block district_lot  ...  \
# 0     Multiple Dwelling  98  LMS3275  None          185  ...
# 1     Multiple Dwelling  40   VAS336  None          185  ...
# 2     Multiple Dwelling  12    LMS49  None          185  ...
# 3     Multiple Dwelling  40  VAS1405  None          185  ...
# 4     Multiple Dwelling  23  VAS1902  None          185  ...
#
#   current_improvement_value tax_assessment_year previous_land_value  \
# 0                  184000.0                2022            355000.0
# ...

# %%
data['report_year'].unique()
# Out:
# array(['2022', '2023', '2024', '2025', '2020', '2021'], dtype=object)

# %%
data.dtypes
# Out:
# pid                            object
# legal_type                     object
# folio                          object
# land_coordinate                object
# zoning_district                object
# zoning_classification          object
# lot                            object
# plan                           object
# block                          object
# district_lot                   object
# from_civic_number              object
# to_civic_number                object
# street_name                    object
# property_postal_code           object
# narrative_legal_line1          object
# narrative_legal_line2          object
# narrative_legal_line3          object
# narrative_legal_line4          object
# narrative_legal_line5          object
# current_land_value            float64
# current_improvement_value     float64
# tax_assessment_year            object
# previous_land_value           float64
# previous_improvement_value    float64
# year_built                     object
# ...

# %%
data.shape
# Out:
# (1324584, 30)

# %%
times = ['2025','2024','2023','2022','2021']

# %%
data_filtered = data[data['report_year'].isin(times)]

# %%
data_filtered.to_parquet('../data/raw/property-tax-report-filtered.parquet')

# %%
data_filtered.shape
# Out:
# (1109781, 30)

# %% [markdown]
# # Second Part

# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_parquet("../data/raw/property-tax-report-filtered.parquet")
data.head()
# Out:
#            pid legal_type         folio land_coordinate zoning_district  \
# 0  024-179-370     STRATA  601109050098        60110905            RM-6
# 1  003-898-121     STRATA  616117750040        61611775           RM-5A
# 2  017-341-248     STRATA  600110060012        60011006            RM-6
# 3  006-473-601     STRATA  616118980040        61611898           RM-5A
# 4  007-742-452     STRATA  611108050023        61110805           RM-5B
#
#   zoning_classification lot     plan block district_lot  ...  \
# 0     Multiple Dwelling  98  LMS3275  None          185  ...
# 1     Multiple Dwelling  40   VAS336  None          185  ...
# 2     Multiple Dwelling  12    LMS49  None          185  ...
# 3     Multiple Dwelling  40  VAS1405  None          185  ...
# 4     Multiple Dwelling  23  VAS1902  None          185  ...
#
#   current_improvement_value tax_assessment_year previous_land_value  \
# 0                  184000.0                2022            355000.0
# ...

# %%
data.shape
# Out:
# (1109781, 30)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1109781 entries, 0 to 1324583
# Data columns (total 30 columns):
#  #   Column                      Non-Null Count    Dtype
# ---  ------                      --------------    -----
#  0   pid                         1107023 non-null  object
#  1   legal_type                  1109781 non-null  object
#  2   folio                       1109781 non-null  object
#  3   land_coordinate             1109781 non-null  object
#  4   zoning_district             1109750 non-null  object
#  5   zoning_classification       1109750 non-null  object
#  6   lot                         1102170 non-null  object
#  7   plan                        1108691 non-null  object
#  8   block                       443046 non-null   object
#  9   district_lot                1055967 non-null  object
#  10  from_civic_number           560904 non-null   object
#  11  to_civic_number             1106959 non-null  object
# ...
